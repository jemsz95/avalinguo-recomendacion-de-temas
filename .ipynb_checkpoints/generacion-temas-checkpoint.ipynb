# %%
import requests
import json
from io import StringIO
import numpy as np

# %%
topics_mx_request = requests.get('https://trends.google.com/trends/api/topcharts?hl=en-US&tz=300&date=2017&geo=MX')
topics_global_request = requests.get('https://trends.google.com/trends/api/topcharts?hl=en-US&tz=300&date=2017&geo=GLOBAL')
cat_request = requests.get('https://gist.githubusercontent.com/Mackaber/545610649e6a32a5723af78d8069369b/raw/3a9889bf1336d9fd3e05882d7d028138e6586374/mexico_interest_dataset.json')

print('Status')
print('Topics MX:', topics_mx_request.status_code)
print('Topics Global:', topics_global_request.status_code)
print('Categories:', cat_request.status_code)
# Out:
# Status
# Topics MX: 200
# Topics Global: 200
# Categories: 200

# %%
top_mx = json.load(StringIO(topics_mx_request.text[topics_mx_request.text.find('\n')+1:]))
top_global = json.load(StringIO(topics_global_request.text[topics_global_request.text.find('\n')+1:]))

categories = cat_request.json()
topics = [item for sublist in top_mx['topCharts'] for item in sublist['listItems']] + [item for sublist in top_global['topCharts'] for item in sublist['listItems']]

unique_topics = set(topics)

# %%
class Category:
    def __init__(self, cat_id, name, parent=None):
        self.weight = 1
        self.name = name
        self.parent = parent
        self.children = []
        self.cat_id = cat_id
        
        if parent is not None:
            parent.add_child(self)
        
    def add_child(self, child):
        self.children.append(child)
        child.parent = self
        
        for c in children:
            c.weight = 1 / len(children)
            
    def add_parent(self, parent):
        parent.add_child(self)
        
    def is_descendant_of(self, cat):
        if(self.parent is None):
            return False
        
        if(self.parent is cat):
            return True
        
        return self.parent.is_descendant_of(cat)
        
class Topic:
    def __init__(self, name, categories=[]):
        self.name = name
        self.categories = categories[:]
        
        # Remover ascendencia de categorias (son redundantes)
        # Complejidad: O(mn^2) donde m es la altura maxima del arbol de categorias.
        # Quizas se pueda mejorar pero dudo que un tema tenga muchas categorias
        for c1 in self.categories:
            for c2 in self.categories:
                if c1.is_descendant_of(c2):
                    self.categories.remove(c1)
    
    
    '''
        Esta funcion retorna un arreglo con los pesos de categoria calculados de la
        siguiunte forma:
        
        - Si la categoria fue asignada al tema, esta tiene un peso de 1
        - Si la categoria es un hijo de una categoria asignada, se pondera
          esta categoria proporcional a la cantidad de hermanos que tiene
        - Si la categoria es padre de una categoria asignada, se pondera esta
          categoria proporcional a la ponderacion del hijo 
    '''
    def categorization_array(self, n_cat):
        mat = np.zeros(n_cat)
        
        for cat in self.categories:
            mat[cat.cat_id] = 1
            
            for ch in cat.children:
                # Cada hijo tiene un peso equivalente a
                # una fraccion del padre
                mat[ch.cat_id] = ch.weight
            
            # Iterar por padres
            par = cat.parent
            w = cat.weight
            while(par is not None):
                # Cada padre tiene un peso equivalente
                # a la fraccion del hijo
                mat[par.cat_id] = w
                w *= par.weight
        
        return mat
# Out:
# {'13 Reasons Why',
#  'Aaron Hernandez',
#  'Accidente en Reforma',
#  'Adam West',
#  'American Gods',
#  'Ana Winocur',
#  'April the Giraffe',
#  'Ariana Grande',
#  'Australian Open',
#  'BMC election',
#  'Baahubali 2: The Conclusion',
#  'Bad and Boujee',
#  'Beauty and the Beast',
#  'Big Brother Brasil',
#  'Bigg Boss',
#  'Bill Paxton',
#  'Bill Skarsgård',
#  'Bimba Bosé',
#  'Bitcoin',
#  'Brad Bufanda',
#  'British Columbia election',
#  'Buen Fin',
#  'Caer en Tentación',
#  'Camila Sodi',
#  'Canelo vs Chávez',
#  'Canelo vs GGG',
#  'Cardi B',
#  'Cash Me Outside Meme',
#  'Cataluña',
#  'Charlie Murphy',
#  'Chester Bennington',
#  'Chicken breast recipe',
#  'Chris Cornell',
#  'Closer',
#  'Coco',
#  'Coleslaw recipe',
#  'Corea del Norte',
#  'Cómo contribuye la brea a los restos fósiles',
#  'Cómo dibujar',
#  'Cómo hacer slime',
#  'Cómo hacer un folleto',
#  'Cómo hacer un spinner',
#  'Cómo hacer una catrina',
#  'Cómo se escribe Halloween',
#  'Cómo se fabrica el vidrio',
#  'Cómo se puede utilizar la energía solar',
#  'Cómo ser un Latin Lover',
#  'Cómo vivían las personas en el antiguo Egipto',
#  'David Cassidy',
#  'Despacito',
#  'Dodgers vs Astros',
#  'Donald Trump',
#  'Dunkirk',
#  'Dutch election',
#  'Eclipse Solar',
#  'Eclipse solar',
#  'Ed Sheeran',
#  'Eduardo Yáñez',
#  'El Señor de los Cielos',
#  'Elecciones Estado de México',
#  'Elf on the Shelf Meme',
#  'Enamorándome de Ramón',
#  'FIFA Confederations Cup',
#  'Fidget Spinner',
#  'Floyd Mayweather',
#  'French election',
#  'French toast recipe',
#  'Gal Gadot',
#  'Game of Thrones',
#  'Game of Thrones Meme',
#  'Gasolinazo',
#  'Georgia special election',
#  'German federal election',
#  'Ground beef recipe',
#  'HUMBLE.',
#  'Harvey Weinstein',
#  'Havana',
#  'Hiromi Hayakawa',
#  'Hot Dog Meme',
#  'How to buy Bitcoin',
#  'How to freeze your credit',
#  'How to lose belly fat fast',
#  'How to make a fidget spinner',
#  'How to make slime',
#  'How to make solar eclipse glasses',
#  'How to play Powerball',
#  'How to screen record',
#  'How to watch Mayweather vs McGregor',
#  'How to watch the solar eclipse',
#  'Hugh Hefner',
#  'Huracán Franklin',
#  'Huracán Harvey',
#  'Huracán Irma',
#  'Huracán Katia',
#  'Hurricane Harvey',
#  'Hurricane Irma',
#  'Hurricane Jose',
#  'Hurricane Maria',
#  'IT',
#  'IT Meme',
#  'India National Cricket Team',
#  'Iron Fist',
#  'It',
#  'Italia vs Suecia',
#  'Jason Momoa',
#  'Javier Duarte',
#  'Joe Biden Meme',
#  'Julio César Chávez Jr.',
#  'Justice League',
#  'Kaley Cuoco',
#  'Karla Luna',
#  'Katy Perry',
#  'Kek tarifi (cake recipe)',
#  'Kendrick Lamar',
#  'Kevin Spacey',
#  'La Bella y la Bestia',
#  'La Isla',
#  'La La Land',
#  'La Piloto',
#  'La doble vida de Estela Carrillo',
#  'Lady Gaga',
#  'Las Vegas Shooting',
#  'Lil Peep',
#  'Lil Pump',
#  'Linkin Park',
#  'Lo que la vida me robó',
#  'Logan',
#  'Look What You Made Me Do',
#  'Louis C.K.',
#  'Lupita Dalessio',
#  'Manchester',
#  'Mariah Carey',
#  'Maru Dueñas',
#  'Matt Lauer',
#  'Mayweather vs McGregor Fight',
#  'Mayweather vs Mcgregor',
#  'Meghan Markle',
#  'Melania Trump',
#  'Mi marido tiene familia',
#  'Michael Flynn',
#  'Millie Bobby Brown',
#  'Mindhunter',
#  'Montana special election',
#  'México vs Alemania',
#  'México vs USA',
#  'NBA Playoffs',
#  'Nadia Toffa',
#  'Nintendo Switch',
#  'Nokia 3310',
#  'Nokia 6',
#  'North Korea',
#  'OnePlus 5',
#  'Oppo F5',
#  'Perfect',
#  'Perú vs Nueva Zelanda',
#  'Pesto recipe',
#  'Philippe Coutinho',
#  'Pork chop recipe',
#  'Poğaça tarifi (Turkish bread recipe)',
#  'Qué es el mecanismo de Antikythera',
#  'Qué es un cuento',
#  'Qué es un eclipse',
#  'Qué es un ecosistema',
#  'Qué es un pangolín',
#  'Qué es un sismo',
#  'Qué es una encuesta',
#  'Qué es una mezcla homogénea',
#  'Qué regiones del mundo se encontraban congeladas',
#  'Qué son las abreviaturas',
#  'Rafa Márquez',
#  'Razer Phone',
#  'Riverdale',
#  'Roblox',
#  'Rockstar',
#  'Romper Meme',
#  'Rosario Tijeras',
#  'Rápido y Furioso 8',
#  'Samsung Galaxy S8',
#  'Saoirse Ronan',
#  'Serie del Caribe',
#  'Shape of You',
#  'Sicilian regional election',
#  'Sismo en México',
#  'Solar Eclipse',
#  'Spaghetti squash recipe',
#  'Spiderman Homecoming',
#  'Spinner',
#  'Spongebob Mocking Meme',
#  'Stranger Things',
#  'Super Bowl',
#  'Súper Bowl',
#  'The Fate of the Furious',
#  'The Kapil Sharma Show',
#  'Thor: Ragnarok',
#  'Tom Holland',
#  'Tom Petty',
#  'Tour de France',
#  'Travis Scott',
#  'UEFA Champions League',
#  'UK election',
#  'US Open',
#  'United Airlines Meme',
#  'Uttar Pradesh election',
#  'Versace on the Floor',
#  'What in Tarnation Meme',
#  'Wimbledon',
#  'Wonder Woman',
#  'World Series',
#  'Xbox One X',
#  'iPhone 8',
#  'iPhone X',
#  '小林 麻央',
#  '餃子 レシピ (Dumpling recipe)'}

# %%
display(categories)
# Out:
# [{'key': 'Interests > Business and industry',
#   'name': 'Business and industry',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Business and industry'},
#  {'audience_size': 10000000,
#   'id': '6003584163107',
#   'key': 'Interests > Business and industry > Advertising',
#   'name': 'Advertising',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Advertising',
#   'type': 'interests'},
#  {'audience_size': 9200000,
#   'id': '6003840140052',
#   'key': 'Interests > Business and industry > Agriculture',
#   'name': 'Agriculture',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Agriculture',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6004140335706',
#   'key': 'Interests > Business and industry > Architecture',
#   'name': 'Architecture',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Architecture',
#   'type': 'interests'},
#  {'audience_size': 5200000,
#   'id': '6002963523717',
#   'key': 'Interests > Business and industry > Aviation',
#   'name': 'Aviation',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Aviation',
#   'type': 'interests'},
#  {'key': 'Interests > Business and industry > Banking',
#   'name': 'Banking',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Banking'},
#  {'audience_size': 690000,
#   'id': '6003063638807',
#   'key': 'Interests > Business and industry > Banking > Investment banking',
#   'name': 'Investment banking',
#   'parent': 'Interests > Business and industry > Banking',
#   'path': ['Interests', 'Business and industry', 'Banking'],
#   'raw_name': 'Investment banking',
#   'type': 'interests'},
#  {'audience_size': 2700000,
#   'id': '6003466585319',
#   'key': 'Interests > Business and industry > Banking > Online banking',
#   'name': 'Online banking',
#   'parent': 'Interests > Business and industry > Banking',
#   'path': ['Interests', 'Business and industry', 'Banking'],
#   'raw_name': 'Online banking',
#   'type': 'interests'},
#  {'audience_size': 590000,
#   'id': '6003062205328',
#   'key': 'Interests > Business and industry > Banking > Retail banking',
#   'name': 'Retail banking',
#   'parent': 'Interests > Business and industry > Banking',
#   'path': ['Interests', 'Business and industry', 'Banking'],
#   'raw_name': 'Retail banking',
#   'type': 'interests'},
#  {'audience_size': 39000000,
#   'id': '6003402305839',
#   'key': 'Interests > Business and industry > Business',
#   'name': 'Business',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Business',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6003395414271',
#   'key': 'Interests > Business and industry > Construction',
#   'name': 'Construction',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Construction',
#   'type': 'interests'},
#  {'key': 'Interests > Business and industry > Design',
#   'name': 'Design',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Design'},
#  {'audience_size': 4000000,
#   'id': '6003266266843',
#   'key': 'Interests > Business and industry > Design > Fashion design',
#   'name': 'Fashion design',
#   'parent': 'Interests > Business and industry > Design',
#   'path': ['Interests', 'Business and industry', 'Design'],
#   'raw_name': 'Fashion design',
#   'type': 'interests'},
#  {'audience_size': 5600000,
#   'id': '6003096002658',
#   'key': 'Interests > Business and industry > Design > Graphic design',
#   'name': 'Graphic design',
#   'parent': 'Interests > Business and industry > Design',
#   'path': ['Interests', 'Business and industry', 'Design'],
#   'raw_name': 'Graphic design',
#   'type': 'interests'},
#  {'audience_size': 9600000,
#   'id': '6002920953955',
#   'key': 'Interests > Business and industry > Design > Interior design',
#   'name': 'Interior design',
#   'parent': 'Interests > Business and industry > Design',
#   'path': ['Interests', 'Business and industry', 'Design'],
#   'raw_name': 'Interior design',
#   'type': 'interests'},
#  {'audience_size': 6800000,
#   'id': '6003656112304',
#   'key': 'Interests > Business and industry > Economics',
#   'name': 'Economics',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Economics',
#   'type': 'interests'},
#  {'audience_size': 7800000,
#   'id': '6003252179711',
#   'key': 'Interests > Business and industry > Engineering',
#   'name': 'Engineering',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Engineering',
#   'type': 'interests'},
#  {'audience_size': 9100000,
#   'id': '6003371567474',
#   'key': 'Interests > Business and industry > Entrepreneurship',
#   'name': 'Entrepreneurship',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Entrepreneurship',
#   'type': 'interests'},
#  {'audience_size': 5900000,
#   'id': '6003464109203',
#   'key': 'Interests > Business and industry > Healthcare',
#   'name': 'Healthcare',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Healthcare',
#   'type': 'interests'},
#  {'audience_size': 20000000,
#   'id': '6003270811593',
#   'key': 'Interests > Business and industry > Higher education',
#   'name': 'Higher education',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Higher education',
#   'type': 'interests'},
#  {'audience_size': 8400000,
#   'id': '6004037932409',
#   'key': 'Interests > Business and industry > Management',
#   'name': 'Management',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Management',
#   'type': 'interests'},
#  {'audience_size': 16000000,
#   'id': '6003279598823',
#   'key': 'Interests > Business and industry > Marketing',
#   'name': 'Marketing',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Marketing',
#   'type': 'interests'},
#  {'audience_size': 4700000,
#   'id': '6003656063078',
#   'key': 'Interests > Business and industry > Nursing',
#   'name': 'Nursing',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Nursing',
#   'type': 'interests'},
#  {'key': 'Interests > Business and industry > Online',
#   'name': 'Online',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Online'},
#  {'audience_size': 1800000,
#   'id': '6003127206524',
#   'key': 'Interests > Business and industry > Online > Digital marketing',
#   'name': 'Digital marketing',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Digital marketing',
#   'type': 'interests'},
#  {'audience_size': 19000,
#   'id': '6003481391264',
#   'key': 'Interests > Business and industry > Online > Display advertising',
#   'name': 'Display advertising',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Display advertising',
#   'type': 'interests'},
#  {'audience_size': 210000,
#   'id': '6003076016339',
#   'key': 'Interests > Business and industry > Online > Email marketing',
#   'name': 'Email marketing',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Email marketing',
#   'type': 'interests'},
#  {'audience_size': 1500000,
#   'id': '6003526234370',
#   'key': 'Interests > Business and industry > Online > Online advertising',
#   'name': 'Online advertising',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Online advertising',
#   'type': 'interests'},
#  {'audience_size': 340000,
#   'id': '6003370636074',
#   'key': 'Interests > Business and industry > Online > Search engine optimisation',
#   'name': 'Search engine optimisation',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Search engine optimisation',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6004030160948',
#   'key': 'Interests > Business and industry > Online > Social media',
#   'name': 'Social media',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Social media',
#   'type': 'interests'},
#  {'audience_size': 170000,
#   'id': '6003389760112',
#   'key': 'Interests > Business and industry > Online > Social media marketing',
#   'name': 'Social media marketing',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Social media marketing',
#   'type': 'interests'},
#  {'audience_size': 390000,
#   'id': '6003402518839',
#   'key': 'Interests > Business and industry > Online > Web design',
#   'name': 'Web design',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Web design',
#   'type': 'interests'},
#  {'audience_size': 350000,
#   'id': '6003290005325',
#   'key': 'Interests > Business and industry > Online > Web development',
#   'name': 'Web development',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Web development',
#   'type': 'interests'},
#  {'audience_size': 280000,
#   'id': '6003387418453',
#   'key': 'Interests > Business and industry > Online > Web hosting',
#   'name': 'Web hosting',
#   'parent': 'Interests > Business and industry > Online',
#   'path': ['Interests', 'Business and industry', 'Online'],
#   'raw_name': 'Web hosting',
#   'type': 'interests'},
#  {'key': 'Interests > Business and industry > Personal finance',
#   'name': 'Personal finance',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Personal finance'},
#  {'audience_size': 19000000,
#   'id': '6003369782940',
#   'key': 'Interests > Business and industry > Personal finance > Credit cards',
#   'name': 'Credit cards',
#   'parent': 'Interests > Business and industry > Personal finance',
#   'path': ['Interests', 'Business and industry', 'Personal finance'],
#   'raw_name': 'Credit cards',
#   'type': 'interests'},
#  {'audience_size': 9800000,
#   'id': '6003217093576',
#   'key': 'Interests > Business and industry > Personal finance > Insurance',
#   'name': 'Insurance',
#   'parent': 'Interests > Business and industry > Personal finance',
#   'path': ['Interests', 'Business and industry', 'Personal finance'],
#   'raw_name': 'Insurance',
#   'type': 'interests'},
#  {'audience_size': 11000000,
#   'id': '6003388314512',
#   'key': 'Interests > Business and industry > Personal finance > Investment',
#   'name': 'Investment',
#   'parent': 'Interests > Business and industry > Personal finance',
#   'path': ['Interests', 'Business and industry', 'Personal finance'],
#   'raw_name': 'Investment',
#   'type': 'interests'},
#  {'audience_size': 2000000,
#   'id': '6003141785766',
#   'key': 'Interests > Business and industry > Personal finance > Mortgage loans',
#   'name': 'Mortgage loans',
#   'parent': 'Interests > Business and industry > Personal finance',
#   'path': ['Interests', 'Business and industry', 'Personal finance'],
#   'raw_name': 'Mortgage loans',
#   'type': 'interests'},
#  {'audience_size': 11000000,
#   'id': '6003578086487',
#   'key': 'Interests > Business and industry > Property',
#   'name': 'Property',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Property',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003778400853',
#   'key': 'Interests > Business and industry > Retail',
#   'name': 'Retail',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Retail',
#   'type': 'interests'},
#  {'audience_size': 26000000,
#   'id': '6003074954515',
#   'key': 'Interests > Business and industry > Sales',
#   'name': 'Sales',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Sales',
#   'type': 'interests'},
#  {'audience_size': 19000000,
#   'id': '6002866718622',
#   'key': 'Interests > Business and industry > Science',
#   'name': 'Science',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Science',
#   'type': 'interests'},
#  {'audience_size': 730000,
#   'id': '6002884511422',
#   'key': 'Interests > Business and industry > Small business',
#   'name': 'Small business',
#   'parent': 'Interests > Business and industry',
#   'path': ['Interests', 'Business and industry'],
#   'raw_name': 'Small business',
#   'type': 'interests'},
#  {'key': 'Interests > Entertainment',
#   'name': 'Entertainment',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Entertainment'},
#  {'key': 'Interests > Entertainment > Films',
#   'name': 'Films',
#   'parent': 'Interests > Entertainment',
#   'path': ['Interests', 'Entertainment'],
#   'raw_name': 'Films'},
#  {'audience_size': 15000000,
#   'id': '6003243604899',
#   'key': 'Interests > Entertainment > Films > Action films',
#   'name': 'Action films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Action films',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003129926917',
#   'key': 'Interests > Entertainment > Films > Animated films',
#   'name': 'Animated films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Animated films',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003605717820',
#   'key': 'Interests > Entertainment > Films > Anime films',
#   'name': 'Anime films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Anime films',
#   'type': 'interests'},
#  {'audience_size': 3000000,
#   'id': '6003157824284',
#   'key': 'Interests > Entertainment > Films > Bollywood films',
#   'name': 'Bollywood films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Bollywood films',
#   'type': 'interests'},
#  {'audience_size': 18000000,
#   'id': '6003161475030',
#   'key': 'Interests > Entertainment > Films > Comedy films',
#   'name': 'Comedy films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Comedy films',
#   'type': 'interests'},
#  {'audience_size': 6200000,
#   'id': '6003373175581',
#   'key': 'Interests > Entertainment > Films > Documentary films',
#   'name': 'Documentary films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Documentary films',
#   'type': 'interests'},
#  {'audience_size': 4200000,
#   'id': '6003375422677',
#   'key': 'Interests > Entertainment > Films > Drama films',
#   'name': 'Drama films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Drama films',
#   'type': 'interests'},
#  {'audience_size': 8700000,
#   'id': '6003178374133',
#   'key': 'Interests > Entertainment > Films > Fantasy films',
#   'name': 'Fantasy films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Fantasy films',
#   'type': 'interests'},
#  {'audience_size': 9500000,
#   'id': '6003656922020',
#   'key': 'Interests > Entertainment > Films > Horror films',
#   'name': 'Horror films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Horror films',
#   'type': 'interests'},
#  {'audience_size': 9200000,
#   'id': '6003351312828',
#   'key': 'Interests > Entertainment > Films > Musical theatre',
#   'name': 'Musical theatre',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Musical theatre',
#   'type': 'interests'},
#  {'audience_size': 7000000,
#   'id': '6003206308286',
#   'key': 'Interests > Entertainment > Films > Science fiction films',
#   'name': 'Science fiction films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Science fiction films',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003225325061',
#   'key': 'Interests > Entertainment > Films > Thriller films',
#   'name': 'Thriller films',
#   'parent': 'Interests > Entertainment > Films',
#   'path': ['Interests', 'Entertainment', 'Films'],
#   'raw_name': 'Thriller films',
#   'type': 'interests'},
#  {'key': 'Interests > Entertainment > Games',
#   'name': 'Games',
#   'parent': 'Interests > Entertainment',
#   'path': ['Interests', 'Entertainment'],
#   'raw_name': 'Games'},
#  {'audience_size': 3300000,
#   'id': '6002971095994',
#   'key': 'Interests > Entertainment > Games > Action games',
#   'name': 'Action games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Action games',
#   'type': 'interests'},
#  {'audience_size': 820000,
#   'id': '6003342470823',
#   'key': 'Interests > Entertainment > Games > Board games',
#   'name': 'Board games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Board games',
#   'type': 'interests'},
#  {'audience_size': 590000,
#   'id': '6003434373937',
#   'key': 'Interests > Entertainment > Games > Browser games',
#   'name': 'Browser games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Browser games',
#   'type': 'interests'},
#  {'audience_size': 2800000,
#   'id': '6003647522546',
#   'key': 'Interests > Entertainment > Games > Card games',
#   'name': 'Card games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Card games',
#   'type': 'interests'},
#  {'audience_size': 200000,
#   'id': '6003248338072',
#   'key': 'Interests > Entertainment > Games > Casino games',
#   'name': 'Casino games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Casino games',
#   'type': 'interests'},
#  {'audience_size': 16000000,
#   'id': '6003059733932',
#   'key': 'Interests > Entertainment > Games > First-person shooter games',
#   'name': 'First-person shooter games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'First-person shooter games',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003012317397',
#   'key': 'Interests > Entertainment > Games > Gambling',
#   'name': 'Gambling',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Gambling',
#   'type': 'interests'},
#  {'audience_size': 690000,
#   'id': '6003176101552',
#   'key': 'Interests > Entertainment > Games > Massively multiplayer online games',
#   'name': 'Massively multiplayer online games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Massively multiplayer online games',
#   'type': 'interests'},
#  {'audience_size': 1300000,
#   'id': '6003198370967',
#   'key': 'Interests > Entertainment > Games > Massively multiplayer online role-playing games',
#   'name': 'Massively multiplayer online role-playing games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Massively multiplayer online role-playing games',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6003153672865',
#   'key': 'Interests > Entertainment > Games > Online games',
#   'name': 'Online games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Online games',
#   'type': 'interests'},
#  {'audience_size': 1100000,
#   'id': '6003030519207',
#   'key': 'Interests > Entertainment > Games > Online poker',
#   'name': 'Online poker',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Online poker',
#   'type': 'interests'},
#  {'audience_size': 4500000,
#   'id': '6003668975718',
#   'key': 'Interests > Entertainment > Games > Puzzle video games',
#   'name': 'Puzzle video games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Puzzle video games',
#   'type': 'interests'},
#  {'audience_size': 2700000,
#   'id': '6003385141743',
#   'key': 'Interests > Entertainment > Games > Racing games',
#   'name': 'Racing games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Racing games',
#   'type': 'interests'},
#  {'audience_size': 2400000,
#   'id': '6003380576181',
#   'key': 'Interests > Entertainment > Games > Role-playing games',
#   'name': 'Role-playing games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Role-playing games',
#   'type': 'interests'},
#  {'audience_size': 2000000,
#   'id': '6003471508663',
#   'key': 'Interests > Entertainment > Games > Shooter games',
#   'name': 'Shooter games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Shooter games',
#   'type': 'interests'},
#  {'audience_size': 2400000,
#   'id': '6003246168013',
#   'key': 'Interests > Entertainment > Games > Simulation games',
#   'name': 'Simulation games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Simulation games',
#   'type': 'interests'},
#  {'audience_size': 3500000,
#   'id': '6003540150873',
#   'key': 'Interests > Entertainment > Games > Sports games',
#   'name': 'Sports games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Sports games',
#   'type': 'interests'},
#  {'audience_size': 560000,
#   'id': '6003582500438',
#   'key': 'Interests > Entertainment > Games > Strategy games',
#   'name': 'Strategy games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Strategy games',
#   'type': 'interests'},
#  {'audience_size': 38000000,
#   'id': '6003940339466',
#   'key': 'Interests > Entertainment > Games > Video games',
#   'name': 'Video games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Video games',
#   'type': 'interests'},
#  {'audience_size': 1000000,
#   'id': '6002964500317',
#   'key': 'Interests > Entertainment > Games > Word games',
#   'name': 'Word games',
#   'parent': 'Interests > Entertainment > Games',
#   'path': ['Interests', 'Entertainment', 'Games'],
#   'raw_name': 'Word games',
#   'type': 'interests'},
#  {'key': 'Interests > Entertainment > Live events',
#   'name': 'Live events',
#   'parent': 'Interests > Entertainment',
#   'path': ['Interests', 'Entertainment'],
#   'raw_name': 'Live events'},
#  {'audience_size': 3600000,
#   'id': '6003247127613',
#   'key': 'Interests > Entertainment > Live events > Ballet',
#   'name': 'Ballet',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Ballet',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003156321008',
#   'key': 'Interests > Entertainment > Live events > Bars',
#   'name': 'Bars',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Bars',
#   'type': 'interests'},
#  {'audience_size': 14000000,
#   'id': '6002970406974',
#   'key': 'Interests > Entertainment > Live events > Concerts',
#   'name': 'Concerts',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Concerts',
#   'type': 'interests'},
#  {'audience_size': 3200000,
#   'id': '6003247890613',
#   'key': 'Interests > Entertainment > Live events > Dancehalls',
#   'name': 'Dancehalls',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Dancehalls',
#   'type': 'interests'},
#  {'audience_size': 7000000,
#   'id': '6003108826384',
#   'key': 'Interests > Entertainment > Live events > Music festivals',
#   'name': 'Music festivals',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Music festivals',
#   'type': 'interests'},
#  {'audience_size': 9000000,
#   'id': '6003361714600',
#   'key': 'Interests > Entertainment > Live events > Nightclubs',
#   'name': 'Nightclubs',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Nightclubs',
#   'type': 'interests'},
#  {'audience_size': 11000000,
#   'id': '6003147868152',
#   'key': 'Interests > Entertainment > Live events > Parties',
#   'name': 'Parties',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Parties',
#   'type': 'interests'},
#  {'audience_size': 7600000,
#   'id': '6003417378239',
#   'key': 'Interests > Entertainment > Live events > Plays',
#   'name': 'Plays',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Plays',
#   'type': 'interests'},
#  {'audience_size': 14000000,
#   'id': '6002957026250',
#   'key': 'Interests > Entertainment > Live events > Theatre',
#   'name': 'Theatre',
#   'parent': 'Interests > Entertainment > Live events',
#   'path': ['Interests', 'Entertainment', 'Live events'],
#   'raw_name': 'Theatre',
#   'type': 'interests'},
#  {'key': 'Interests > Entertainment > Music',
#   'name': 'Music',
#   'parent': 'Interests > Entertainment',
#   'path': ['Interests', 'Entertainment'],
#   'raw_name': 'Music'},
#  {'audience_size': 11000000,
#   'id': '6003257757682',
#   'key': 'Interests > Entertainment > Music > Blues music',
#   'name': 'Blues music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Blues music',
#   'type': 'interests'},
#  {'audience_size': 8300000,
#   'id': '6002951587955',
#   'key': 'Interests > Entertainment > Music > Classical music',
#   'name': 'Classical music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Classical music',
#   'type': 'interests'},
#  {'audience_size': 5200000,
#   'id': '6003493980595',
#   'key': 'Interests > Entertainment > Music > Country music',
#   'name': 'Country music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Country music',
#   'type': 'interests'},
#  {'audience_size': 6300000,
#   'id': '6003179515414',
#   'key': 'Interests > Entertainment > Music > Dance music',
#   'name': 'Dance music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Dance music',
#   'type': 'interests'},
#  {'audience_size': 19000000,
#   'id': '6003902397066',
#   'key': 'Interests > Entertainment > Music > Electronic music',
#   'name': 'Electronic music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Electronic music',
#   'type': 'interests'},
#  {'audience_size': 5000000,
#   'id': '6003071094715',
#   'key': 'Interests > Entertainment > Music > Gospel music',
#   'name': 'Gospel music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Gospel music',
#   'type': 'interests'},
#  {'audience_size': 13000000,
#   'id': '6003633122583',
#   'key': 'Interests > Entertainment > Music > Heavy metal music',
#   'name': 'Heavy metal music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Heavy metal music',
#   'type': 'interests'},
#  {'audience_size': 20000000,
#   'id': '6003225556345',
#   'key': 'Interests > Entertainment > Music > Hip hop music',
#   'name': 'Hip hop music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Hip hop music',
#   'type': 'interests'},
#  {'audience_size': 8100000,
#   'id': '6003146442552',
#   'key': 'Interests > Entertainment > Music > Jazz music',
#   'name': 'Jazz music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Jazz music',
#   'type': 'interests'},
#  {'audience_size': 28000000,
#   'id': '6003332483177',
#   'key': 'Interests > Entertainment > Music > Music videos',
#   'name': 'Music videos',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Music videos',
#   'type': 'interests'},
#  {'audience_size': 30000000,
#   'id': '6003341579196',
#   'key': 'Interests > Entertainment > Music > Pop music',
#   'name': 'Pop music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Pop music',
#   'type': 'interests'},
#  {'audience_size': 15000000,
#   'id': '6003195554098',
#   'key': 'Interests > Entertainment > Music > Rhythm and blues music',
#   'name': 'Rhythm and blues music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Rhythm and blues music',
#   'type': 'interests'},
#  {'audience_size': 27000000,
#   'id': '6003582732907',
#   'key': 'Interests > Entertainment > Music > Rock music',
#   'name': 'Rock music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Rock music',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003107699532',
#   'key': 'Interests > Entertainment > Music > Soul music',
#   'name': 'Soul music',
#   'parent': 'Interests > Entertainment > Music',
#   'path': ['Interests', 'Entertainment', 'Music'],
#   'raw_name': 'Soul music',
#   'type': 'interests'},
#  {'key': 'Interests > Entertainment > Reading',
#   'name': 'Reading',
#   'parent': 'Interests > Entertainment',
#   'path': ['Interests', 'Entertainment'],
#   'raw_name': 'Reading'},
#  {'audience_size': 25000000,
#   'id': '6003462707303',
#   'key': 'Interests > Entertainment > Reading > Books',
#   'name': 'Books',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Books',
#   'type': 'interests'},
#  {'audience_size': 6500000,
#   'id': '6003126215349',
#   'key': 'Interests > Entertainment > Reading > Comics',
#   'name': 'Comics',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Comics',
#   'type': 'interests'},
#  {'audience_size': 7900000,
#   'id': '6003274262708',
#   'key': 'Interests > Entertainment > Reading > Fiction books',
#   'name': 'Fiction books',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Fiction books',
#   'type': 'interests'},
#  {'audience_size': 14000000,
#   'id': '6003247790075',
#   'key': 'Interests > Entertainment > Reading > Literature',
#   'name': 'Literature',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Literature',
#   'type': 'interests'},
#  {'audience_size': 17000000,
#   'id': '6003206216430',
#   'key': 'Interests > Entertainment > Reading > Magazines',
#   'name': 'Magazines',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Magazines',
#   'type': 'interests'},
#  {'audience_size': 7500000,
#   'id': '6003083357650',
#   'key': 'Interests > Entertainment > Reading > Manga',
#   'name': 'Manga',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Manga',
#   'type': 'interests'},
#  {'audience_size': 4000000,
#   'id': '6002986104968',
#   'key': 'Interests > Entertainment > Reading > Mystery fiction',
#   'name': 'Mystery fiction',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Mystery fiction',
#   'type': 'interests'},
#  {'audience_size': 22000000,
#   'id': '6004043913548',
#   'key': 'Interests > Entertainment > Reading > Newspapers',
#   'name': 'Newspapers',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Newspapers',
#   'type': 'interests'},
#  {'audience_size': 82000,
#   'id': '6003420644631',
#   'key': 'Interests > Entertainment > Reading > Non-fiction books',
#   'name': 'Non-fiction books',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Non-fiction books',
#   'type': 'interests'},
#  {'audience_size': 2800000,
#   'id': '6003210799924',
#   'key': 'Interests > Entertainment > Reading > Romance novels',
#   'name': 'Romance novels',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'Romance novels',
#   'type': 'interests'},
#  {'audience_size': 7400000,
#   'id': '6003074487739',
#   'key': 'Interests > Entertainment > Reading > eBooks',
#   'name': 'eBooks',
#   'parent': 'Interests > Entertainment > Reading',
#   'path': ['Interests', 'Entertainment', 'Reading'],
#   'raw_name': 'eBooks',
#   'type': 'interests'},
#  {'key': 'Interests > Entertainment > Television programme',
#   'name': 'Television programme',
#   'parent': 'Interests > Entertainment',
#   'path': ['Interests', 'Entertainment'],
#   'raw_name': 'Television programme'},
#  {'audience_size': 1500000,
#   'id': '6003172448161',
#   'key': 'Interests > Entertainment > Television programme > TV chat shows',
#   'name': 'TV chat shows',
#   'parent': 'Interests > Entertainment > Television programme',
#   'path': ['Interests', 'Entertainment', 'Television programme'],
#   'raw_name': 'TV chat shows',
#   'type': 'interests'},
#  {'audience_size': 1700000,
#   'id': '6003305361460',
#   'key': 'Interests > Entertainment > Television programme > TV comedies',
#   'name': 'TV comedies',
#   'parent': 'Interests > Entertainment > Television programme',
#   'path': ['Interests', 'Entertainment', 'Television programme'],
#   'raw_name': 'TV comedies',
#   'type': 'interests'},
#  {'audience_size': 4400000,
#   'id': '6003126358188',
#   'key': 'Interests > Entertainment > Television programme > TV game shows',
#   'name': 'TV game shows',
#   'parent': 'Interests > Entertainment > Television programme',
#   'path': ['Interests', 'Entertainment', 'Television programme'],
#   'raw_name': 'TV game shows',
#   'type': 'interests'},
#  {'audience_size': 13000000,
#   'id': '6003268182136',
#   'key': 'Interests > Entertainment > Television programme > TV reality shows',
#   'name': 'TV reality shows',
#   'parent': 'Interests > Entertainment > Television programme',
#   'path': ['Interests', 'Entertainment', 'Television programme'],
#   'raw_name': 'TV reality shows',
#   'type': 'interests'},
#  {'key': 'Interests > Family and relationships',
#   'name': 'Family and relationships',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Family and relationships'},
#  {'audience_size': 11000000,
#   'id': '6003198851865',
#   'key': 'Interests > Family and relationships > Dating',
#   'name': 'Dating',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Dating',
#   'type': 'interests'},
#  {'audience_size': 47000000,
#   'id': '6003476182657',
#   'key': 'Interests > Family and relationships > Family',
#   'name': 'Family',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Family',
#   'type': 'interests'},
#  {'audience_size': 14000000,
#   'id': '6003101323797',
#   'key': 'Interests > Family and relationships > Fatherhood',
#   'name': 'Fatherhood',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Fatherhood',
#   'type': 'interests'},
#  {'audience_size': 39000000,
#   'id': '6004100985609',
#   'key': 'Interests > Family and relationships > Friendship',
#   'name': 'Friendship',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Friendship',
#   'type': 'interests'},
#  {'audience_size': 4200000,
#   'id': '6003445506042',
#   'key': 'Interests > Family and relationships > Marriage',
#   'name': 'Marriage',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Marriage',
#   'type': 'interests'},
#  {'audience_size': 22000000,
#   'id': '6002991239659',
#   'key': 'Interests > Family and relationships > Motherhood',
#   'name': 'Motherhood',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Motherhood',
#   'type': 'interests'},
#  {'audience_size': 1400000,
#   'id': '6003232518610',
#   'key': 'Interests > Family and relationships > Parenting',
#   'name': 'Parenting',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Parenting',
#   'type': 'interests'},
#  {'audience_size': 7700000,
#   'id': '6003409392877',
#   'key': 'Interests > Family and relationships > Weddings',
#   'name': 'Weddings',
#   'parent': 'Interests > Family and relationships',
#   'path': ['Interests', 'Family and relationships'],
#   'raw_name': 'Weddings',
#   'type': 'interests'},
#  {'key': 'Interests > Fitness and wellness',
#   'name': 'Fitness and wellness',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Fitness and wellness'},
#  {'audience_size': 2500000,
#   'id': '6003648059946',
#   'key': 'Interests > Fitness and wellness > Bodybuilding',
#   'name': 'Bodybuilding',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Bodybuilding',
#   'type': 'interests'},
#  {'audience_size': 9700000,
#   'id': '6003012185129',
#   'key': 'Interests > Fitness and wellness > Meditation',
#   'name': 'Meditation',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Meditation',
#   'type': 'interests'},
#  {'audience_size': 17000000,
#   'id': '6004115167424',
#   'key': 'Interests > Fitness and wellness > Physical exercise',
#   'name': 'Physical exercise',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Physical exercise',
#   'type': 'interests'},
#  {'audience_size': 15000000,
#   'id': '6003277229371',
#   'key': 'Interests > Fitness and wellness > Physical fitness',
#   'name': 'Physical fitness',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Physical fitness',
#   'type': 'interests'},
#  {'audience_size': 4200000,
#   'id': '6003397496347',
#   'key': 'Interests > Fitness and wellness > Running',
#   'name': 'Running',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Running',
#   'type': 'interests'},
#  {'audience_size': 2400000,
#   'id': '6003473077165',
#   'key': 'Interests > Fitness and wellness > Weight training',
#   'name': 'Weight training',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Weight training',
#   'type': 'interests'},
#  {'audience_size': 6700000,
#   'id': '6003306084421',
#   'key': 'Interests > Fitness and wellness > Yoga',
#   'name': 'Yoga',
#   'parent': 'Interests > Fitness and wellness',
#   'path': ['Interests', 'Fitness and wellness'],
#   'raw_name': 'Yoga',
#   'type': 'interests'},
#  {'key': 'Interests > Food and drink',
#   'name': 'Food and drink',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Food and drink'},
#  {'key': 'Interests > Food and drink > Alcoholic drink',
#   'name': 'Alcoholic drink',
#   'parent': 'Interests > Food and drink',
#   'path': ['Interests', 'Food and drink'],
#   'raw_name': 'Alcoholic drink'},
#  {'audience_size': 19000000,
#   'id': '6003012461997',
#   'key': 'Interests > Food and drink > Alcoholic drink > Beer',
#   'name': 'Beer',
#   'parent': 'Interests > Food and drink > Alcoholic drink',
#   'path': ['Interests', 'Food and drink', 'Alcoholic drink'],
#   'raw_name': 'Beer',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6003146729229',
#   'key': 'Interests > Food and drink > Alcoholic drink > Distilled drinks',
#   'name': 'Distilled drinks',
#   'parent': 'Interests > Food and drink > Alcoholic drink',
#   'path': ['Interests', 'Food and drink', 'Alcoholic drink'],
#   'raw_name': 'Distilled drinks',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6003148544265',
#   'key': 'Interests > Food and drink > Alcoholic drink > Wine',
#   'name': 'Wine',
#   'parent': 'Interests > Food and drink > Alcoholic drink',
#   'path': ['Interests', 'Food and drink', 'Alcoholic drink'],
#   'raw_name': 'Wine',
#   'type': 'interests'},
#  {'key': 'Interests > Food and drink > Cooking',
#   'name': 'Cooking',
#   'parent': 'Interests > Food and drink',
#   'path': ['Interests', 'Food and drink'],
#   'raw_name': 'Cooking'},
#  {'audience_size': 5300000,
#   'id': '6003134986700',
#   'key': 'Interests > Food and drink > Cooking > Baking',
#   'name': 'Baking',
#   'parent': 'Interests > Food and drink > Cooking',
#   'path': ['Interests', 'Food and drink', 'Cooking'],
#   'raw_name': 'Baking',
#   'type': 'interests'},
#  {'audience_size': 15000000,
#   'id': '6003385609165',
#   'key': 'Interests > Food and drink > Cooking > Recipes',
#   'name': 'Recipes',
#   'parent': 'Interests > Food and drink > Cooking',
#   'path': ['Interests', 'Food and drink', 'Cooking'],
#   'raw_name': 'Recipes',
#   'type': 'interests'},
#  {'key': 'Interests > Food and drink > Cuisine',
#   'name': 'Cuisine',
#   'parent': 'Interests > Food and drink',
#   'path': ['Interests', 'Food and drink'],
#   'raw_name': 'Cuisine'},
#  {'audience_size': 1700000,
#   'id': '6003030029655',
#   'key': 'Interests > Food and drink > Cuisine > Chinese cuisine',
#   'name': 'Chinese cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Chinese cuisine',
#   'type': 'interests'},
#  {'audience_size': 1300000,
#   'id': '6003420024431',
#   'key': 'Interests > Food and drink > Cuisine > French Cuisine',
#   'name': 'French Cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'French Cuisine',
#   'type': 'interests'},
#  {'audience_size': 240000,
#   'id': '6004094205989',
#   'key': 'Interests > Food and drink > Cuisine > German cuisine',
#   'name': 'German cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'German cuisine',
#   'type': 'interests'},
#  {'audience_size': 170000,
#   'id': '6003306415421',
#   'key': 'Interests > Food and drink > Cuisine > Greek cuisine',
#   'name': 'Greek cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Greek cuisine',
#   'type': 'interests'},
#  {'audience_size': 570000,
#   'id': '6003494675627',
#   'key': 'Interests > Food and drink > Cuisine > Indian cuisine',
#   'name': 'Indian cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Indian cuisine',
#   'type': 'interests'},
#  {'audience_size': 1300000,
#   'id': '6003102729234',
#   'key': 'Interests > Food and drink > Cuisine > Italian cuisine',
#   'name': 'Italian cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Italian cuisine',
#   'type': 'interests'},
#  {'audience_size': 4300000,
#   'id': '6002998123892',
#   'key': 'Interests > Food and drink > Cuisine > Japanese cuisine',
#   'name': 'Japanese cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Japanese cuisine',
#   'type': 'interests'},
#  {'audience_size': 1700000,
#   'id': '6003343485089',
#   'key': 'Interests > Food and drink > Cuisine > Korean cuisine',
#   'name': 'Korean cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Korean cuisine',
#   'type': 'interests'},
#  {'audience_size': 2200000,
#   'id': '6003102988840',
#   'key': 'Interests > Food and drink > Cuisine > Latin American cuisine',
#   'name': 'Latin American cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Latin American cuisine',
#   'type': 'interests'},
#  {'audience_size': 9400000,
#   'id': '6002964239317',
#   'key': 'Interests > Food and drink > Cuisine > Mexican Cuisine',
#   'name': 'Mexican Cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Mexican Cuisine',
#   'type': 'interests'},
#  {'audience_size': 260000,
#   'id': '6003200340482',
#   'key': 'Interests > Food and drink > Cuisine > Middle Eastern cuisine',
#   'name': 'Middle Eastern cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Middle Eastern cuisine',
#   'type': 'interests'},
#  {'audience_size': 390000,
#   'id': '6003108649035',
#   'key': 'Interests > Food and drink > Cuisine > Spanish cuisine',
#   'name': 'Spanish cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Spanish cuisine',
#   'type': 'interests'},
#  {'audience_size': 210000,
#   'id': '6003283801502',
#   'key': 'Interests > Food and drink > Cuisine > Thai cuisine',
#   'name': 'Thai cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Thai cuisine',
#   'type': 'interests'},
#  {'audience_size': 230000,
#   'id': '6003346311730',
#   'key': 'Interests > Food and drink > Cuisine > Vietnamese cuisine',
#   'name': 'Vietnamese cuisine',
#   'parent': 'Interests > Food and drink > Cuisine',
#   'path': ['Interests', 'Food and drink', 'Cuisine'],
#   'raw_name': 'Vietnamese cuisine',
#   'type': 'interests'},
#  {'key': 'Interests > Food and drink > Drinks',
#   'name': 'Drinks',
#   'parent': 'Interests > Food and drink',
#   'path': ['Interests', 'Food and drink'],
#   'raw_name': 'Drinks'},
#  {'audience_size': 19000000,
#   'id': '6003626773307',
#   'key': 'Interests > Food and drink > Drinks > Coffee',
#   'name': 'Coffee',
#   'parent': 'Interests > Food and drink > Drinks',
#   'path': ['Interests', 'Food and drink', 'Drinks'],
#   'raw_name': 'Coffee',
#   'type': 'interests'},
#  {'audience_size': 2900000,
#   'id': '6003392512725',
#   'key': 'Interests > Food and drink > Drinks > Energy drinks',
#   'name': 'Energy drinks',
#   'parent': 'Interests > Food and drink > Drinks',
#   'path': ['Interests', 'Food and drink', 'Drinks'],
#   'raw_name': 'Energy drinks',
#   'type': 'interests'},
#  {'audience_size': 5900000,
#   'id': '6003703931713',
#   'key': 'Interests > Food and drink > Drinks > Juice',
#   'name': 'Juice',
#   'parent': 'Interests > Food and drink > Drinks',
#   'path': ['Interests', 'Food and drink', 'Drinks'],
#   'raw_name': 'Juice',
# ...
#   'name': 'Discount shops',
#   'parent': 'Interests > Shopping and fashion > Shopping',
#   'path': ['Interests', 'Shopping and fashion', 'Shopping'],
#   'raw_name': 'Discount shops',
#   'type': 'interests'},
#  {'audience_size': 13000000,
#   'id': '6007828099136',
#   'key': 'Interests > Shopping and fashion > Shopping > Luxury goods',
#   'name': 'Luxury goods',
#   'parent': 'Interests > Shopping and fashion > Shopping',
#   'path': ['Interests', 'Shopping and fashion', 'Shopping'],
#   'raw_name': 'Luxury goods',
#   'type': 'interests'},
#  {'audience_size': 38000000,
#   'id': '6003346592981',
#   'key': 'Interests > Shopping and fashion > Shopping > Online shopping',
#   'name': 'Online shopping',
#   'parent': 'Interests > Shopping and fashion > Shopping',
#   'path': ['Interests', 'Shopping and fashion', 'Shopping'],
#   'raw_name': 'Online shopping',
#   'type': 'interests'},
#  {'audience_size': 7800000,
#   'id': '6003390752144',
#   'key': 'Interests > Shopping and fashion > Shopping > Shopping centres',
#   'name': 'Shopping centres',
#   'parent': 'Interests > Shopping and fashion > Shopping',
#   'path': ['Interests', 'Shopping and fashion', 'Shopping'],
#   'raw_name': 'Shopping centres',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6003070122382',
#   'key': 'Interests > Shopping and fashion > Toys',
#   'name': 'Toys',
#   'parent': 'Interests > Shopping and fashion',
#   'path': ['Interests', 'Shopping and fashion'],
#   'raw_name': 'Toys',
#   'type': 'interests'},
#  {'key': 'Interests > Sports and outdoors',
#   'name': 'Sports and outdoors',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Sports and outdoors'},
#  {'key': 'Interests > Sports and outdoors > Outdoor recreation',
#   'name': 'Outdoor recreation',
#   'parent': 'Interests > Sports and outdoors',
#   'path': ['Interests', 'Sports and outdoors'],
#   'raw_name': 'Outdoor recreation'},
#  {'audience_size': 390000,
#   'id': '6003122958658',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Boating',
#   'name': 'Boating',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Boating',
#   'type': 'interests'},
#  {'audience_size': 3800000,
#   'id': '6003348662930',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Camping',
#   'name': 'Camping',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Camping',
#   'type': 'interests'},
#  {'audience_size': 3100000,
#   'id': '6002979499920',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Fishing',
#   'name': 'Fishing',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Fishing',
#   'type': 'interests'},
#  {'audience_size': 2600000,
#   'id': '6003779859852',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Horseback riding',
#   'name': 'Horseback riding',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Horseback riding',
#   'type': 'interests'},
#  {'audience_size': 3700000,
#   'id': '6003106813190',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Hunting',
#   'name': 'Hunting',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Hunting',
#   'type': 'interests'},
#  {'audience_size': 1200000,
#   'id': '6003092330156',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Mountain biking',
#   'name': 'Mountain biking',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Mountain biking',
#   'type': 'interests'},
#  {'audience_size': 4500000,
#   'id': '6002984573619',
#   'key': 'Interests > Sports and outdoors > Outdoor recreation > Surfing',
#   'name': 'Surfing',
#   'parent': 'Interests > Sports and outdoors > Outdoor recreation',
#   'path': ['Interests', 'Sports and outdoors', 'Outdoor recreation'],
#   'raw_name': 'Surfing',
#   'type': 'interests'},
#  {'key': 'Interests > Sports and outdoors > Sports',
#   'name': 'Sports',
#   'parent': 'Interests > Sports and outdoors',
#   'path': ['Interests', 'Sports and outdoors'],
#   'raw_name': 'Sports'},
#  {'audience_size': 10000000,
#   'id': '6003376089674',
#   'key': 'Interests > Sports and outdoors > Sports > American football',
#   'name': 'American football',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'American football',
#   'type': 'interests'},
#  {'audience_size': 23000000,
#   'id': '6003087413192',
#   'key': 'Interests > Sports and outdoors > Sports > Baseball',
#   'name': 'Baseball',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Baseball',
#   'type': 'interests'},
#  {'audience_size': 22000000,
#   'id': '6003369240775',
#   'key': 'Interests > Sports and outdoors > Sports > Basketball',
#   'name': 'Basketball',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Basketball',
#   'type': 'interests'},
#  {'audience_size': 6400000,
#   'id': '6003146718552',
#   'key': 'Interests > Sports and outdoors > Sports > Car racing',
#   'name': 'Car racing',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Car racing',
#   'type': 'interests'},
#  {'audience_size': 3800000,
#   'id': '6003162931434',
#   'key': 'Interests > Sports and outdoors > Sports > College football',
#   'name': 'College football',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'College football',
#   'type': 'interests'},
#  {'audience_size': 50000000,
#   'id': '6003107902433',
#   'key': 'Interests > Sports and outdoors > Sports > Football',
#   'name': 'Football',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Football',
#   'type': 'interests'},
#  {'audience_size': 3800000,
#   'id': '6003510075864',
#   'key': 'Interests > Sports and outdoors > Sports > Golf',
#   'name': 'Golf',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Golf',
#   'type': 'interests'},
#  {'audience_size': 3000000,
#   'id': '6003424404140',
#   'key': 'Interests > Sports and outdoors > Sports > Marathons',
#   'name': 'Marathons',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Marathons',
#   'type': 'interests'},
#  {'audience_size': 1900000,
#   'id': '6003324287371',
#   'key': 'Interests > Sports and outdoors > Sports > Skiing',
#   'name': 'Skiing',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Skiing',
#   'type': 'interests'},
#  {'audience_size': 1900000,
#   'id': '6003512053894',
#   'key': 'Interests > Sports and outdoors > Sports > Snowboarding',
#   'name': 'Snowboarding',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Snowboarding',
#   'type': 'interests'},
#  {'audience_size': 4400000,
#   'id': '6003166397215',
#   'key': 'Interests > Sports and outdoors > Sports > Swimming',
#   'name': 'Swimming',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Swimming',
#   'type': 'interests'},
#  {'audience_size': 14000000,
#   'id': '6003397425735',
#   'key': 'Interests > Sports and outdoors > Sports > Tennis',
#   'name': 'Tennis',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Tennis',
#   'type': 'interests'},
#  {'audience_size': 590000,
#   'id': '6003351764757',
#   'key': 'Interests > Sports and outdoors > Sports > Triathlons',
#   'name': 'Triathlons',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Triathlons',
#   'type': 'interests'},
#  {'audience_size': 9400000,
#   'id': '6002929380259',
#   'key': 'Interests > Sports and outdoors > Sports > Volleyball',
#   'name': 'Volleyball',
#   'parent': 'Interests > Sports and outdoors > Sports',
#   'path': ['Interests', 'Sports and outdoors', 'Sports'],
#   'raw_name': 'Volleyball',
#   'type': 'interests'},
#  {'key': 'Interests > Technology',
#   'name': 'Technology',
#   'parent': 'Interests',
#   'path': ['Interests'],
#   'raw_name': 'Technology'},
#  {'key': 'Interests > Technology > Computers',
#   'name': 'Computers',
#   'parent': 'Interests > Technology',
#   'path': ['Interests', 'Technology'],
#   'raw_name': 'Computers'},
#  {'audience_size': 260000,
#   'id': '6003349175527',
#   'key': 'Interests > Technology > Computers > Computer memory',
#   'name': 'Computer memory',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Computer memory',
#   'type': 'interests'},
#  {'audience_size': 2800000,
#   'id': '6003116038942',
#   'key': 'Interests > Technology > Computers > Computer monitors',
#   'name': 'Computer monitors',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Computer monitors',
#   'type': 'interests'},
#  {'audience_size': 2700000,
#   'id': '6003142705949',
#   'key': 'Interests > Technology > Computers > Computer processors',
#   'name': 'Computer processors',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Computer processors',
#   'type': 'interests'},
#  {'audience_size': 2200000,
#   'id': '6003151951349',
#   'key': 'Interests > Technology > Computers > Computer servers',
#   'name': 'Computer servers',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Computer servers',
#   'type': 'interests'},
#  {'audience_size': 2900000,
#   'id': '6003115804542',
#   'key': 'Interests > Technology > Computers > Desktop computers',
#   'name': 'Desktop computers',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Desktop computers',
#   'type': 'interests'},
#  {'audience_size': 16000000,
#   'id': '6003423416540',
#   'key': 'Interests > Technology > Computers > Free software',
#   'name': 'Free software',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Free software',
#   'type': 'interests'},
#  {'audience_size': 1400000,
#   'id': '6003629266583',
#   'key': 'Interests > Technology > Computers > Hard drives',
#   'name': 'Hard drives',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Hard drives',
#   'type': 'interests'},
#  {'audience_size': 150000,
#   'id': '6003656296104',
#   'key': 'Interests > Technology > Computers > Network storage',
#   'name': 'Network storage',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Network storage',
#   'type': 'interests'},
#  {'audience_size': 27000000,
#   'id': '6005609368513',
#   'key': 'Interests > Technology > Computers > Software',
#   'name': 'Software',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Software',
#   'type': 'interests'},
#  {'audience_size': 7400000,
#   'id': '6002960574320',
#   'key': 'Interests > Technology > Computers > Tablet computers',
#   'name': 'Tablet computers',
#   'parent': 'Interests > Technology > Computers',
#   'path': ['Interests', 'Technology', 'Computers'],
#   'raw_name': 'Tablet computers',
#   'type': 'interests'},
#  {'key': 'Interests > Technology > Consumer electronics',
#   'name': 'Consumer electronics',
#   'parent': 'Interests > Technology',
#   'path': ['Interests', 'Technology'],
#   'raw_name': 'Consumer electronics'},
#  {'audience_size': 210000,
#   'id': '6003729124262',
#   'key': 'Interests > Technology > Consumer electronics > Audio equipment',
#   'name': 'Audio equipment',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Audio equipment',
#   'type': 'interests'},
#  {'audience_size': 290000,
#   'id': '6002998517244',
#   'key': 'Interests > Technology > Consumer electronics > Camcorders',
#   'name': 'Camcorders',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Camcorders',
#   'type': 'interests'},
#  {'audience_size': 10000000,
#   'id': '6003325186571',
#   'key': 'Interests > Technology > Consumer electronics > Cameras',
#   'name': 'Cameras',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Cameras',
#   'type': 'interests'},
#  {'audience_size': 330000,
#   'id': '6003280676501',
#   'key': 'Interests > Technology > Consumer electronics > GPS devices',
#   'name': 'GPS devices',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'GPS devices',
#   'type': 'interests'},
#  {'audience_size': 12000000,
#   'id': '6003943667466',
#   'key': 'Interests > Technology > Consumer electronics > Game consoles',
#   'name': 'Game consoles',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Game consoles',
#   'type': 'interests'},
#  {'audience_size': 32000000,
#   'id': '6002971085794',
#   'key': 'Interests > Technology > Consumer electronics > Mobile phones',
#   'name': 'Mobile phones',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Mobile phones',
#   'type': 'interests'},
#  {'audience_size': 190000,
#   'id': '6003381994165',
#   'key': 'Interests > Technology > Consumer electronics > Portable media players',
#   'name': 'Portable media players',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Portable media players',
#   'type': 'interests'},
#  {'audience_size': 98000,
#   'id': '6003288647527',
#   'key': 'Interests > Technology > Consumer electronics > Projectors',
#   'name': 'Projectors',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Projectors',
#   'type': 'interests'},
#  {'audience_size': 18000000,
#   'id': '6003289911338',
#   'key': 'Interests > Technology > Consumer electronics > Smartphones',
#   'name': 'Smartphones',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Smartphones',
#   'type': 'interests'},
#  {'audience_size': 39000000,
#   'id': '6003224441249',
#   'key': 'Interests > Technology > Consumer electronics > Televisions',
#   'name': 'Televisions',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'Televisions',
#   'type': 'interests'},
#  {'audience_size': 180000,
#   'id': '6008832464480',
#   'key': 'Interests > Technology > Consumer electronics > eBook readers',
#   'name': 'eBook readers',
#   'parent': 'Interests > Technology > Consumer electronics',
#   'path': ['Interests', 'Technology', 'Consumer electronics'],
#   'raw_name': 'eBook readers',
#   'type': 'interests'}]
